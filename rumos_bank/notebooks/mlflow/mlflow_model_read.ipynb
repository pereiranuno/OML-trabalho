# %% [markdown]
# # Bibliotecas

# %% [markdown]
# ---

# %%
import mlflow
import pandas as pd
from pathlib import Path

# %%
ROOT_PATH = '../../data/'

# %%
uri = "http://localhost:5000"

mlflow.set_tracking_uri(uri)

# %%
model_name = "random_forest"
model_version = "champion"

model = mlflow.pyfunc.load_model(f"models:/{model_name}@{model_version}")
model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: random_forest
#   flavor: mlflow.sklearn
#   run_id: 4b95acdff3df40c0834fea3e8e21e949

# %%
data_path = '../../data/ending_data.csv'
df = pd.read_csv(ROOT_PATH + 'lending_data.csv')

# %%
input_data = df.loc[df['default.payment.next.month'] == 1].sample(10)

input_data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 16825  16826   100000.0    1          2         2   44      0      0      0
# 11615  11616    50000.0    2          2         2   26     -1     -1     -1
# 16858  16859   160000.0    1          1         1   47      1      2      2
# 1225    1226    20000.0    1          3         2   22      0      0      0
# 17775  17776   100000.0    2          2         1   58      2      2      2
# 10895  10896   630000.0    2          1         2   29      0      0      0
# 8007    8008   360000.0    2          1         2   29     -1     -1     -1
# 10575  10576   100000.0    1          1         2   31      2      2      2
# 8117    8118   150000.0    1          1         2   42      2      0      0
# 1800    1801   160000.0    2          2         1   35     -1     -1     -1
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 16825     -1  ...     1537.0     1642.0      110.0    1068.0    1007.0
# 11615     -1  ...      780.0        0.0        0.0     390.0       0.0
# 16858      2  ...    61518.0    65152.0    64074.0       0.0    3200.0
# 1225      -2  ...        0.0        0.0        0.0    1000.0       0.0
# 17775      0  ...    87095.0    88357.0    77155.0    3500.0       0.0
# 10895      0  ...   435019.0   329476.0   338557.0   15868.0   12371.0
# 8007       0  ...    19183.0    36842.0    10621.0    3050.0    9118.0
# 10575      2  ...    88859.0    90685.0    92736.0    4100.0    3300.0
# 8117       0  ...    70034.0    44311.0    20056.0    6482.0    3440.0
# 1800      -1  ...      776.0     1172.0      380.0    1172.0     380.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# 16825    1741.0    1646.0     100.0       0.0                           1
# 11615     780.0       0.0       0.0       0.0                           1
# 16858    3000.0    5000.0       0.0    3000.0                           1
# 1225        0.0       0.0       0.0       0.0                           1
# 17775    3300.0    2839.0    3000.0    4000.0                           1
# 10895   26454.0    8510.0   11039.0    5390.0                           1
# 8007    11000.0   30000.0     428.0    3166.0                           1
# 10575    3500.0    3400.0    3700.0    4000.0                           1
# 8117     2046.0    4311.0    5056.0    1169.0                           1
# 1800      776.0    1172.0     380.0     776.0                           1
#
# [10 rows x 25 columns]

# %%
model.predict(input_data.drop("default.payment.next.month", axis=1))
# Out:
# array([0, 0, 1, 0, 1, 0, 0, 1, 0, 0])
